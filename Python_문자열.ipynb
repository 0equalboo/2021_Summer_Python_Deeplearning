# %% [markdown]
# <a href="https://colab.research.google.com/github/0equalboo/2021_Summer_Python_Deeplearning/blob/main/Python_%EB%AC%B8%EC%9E%90%EC%97%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **문자열**
# * 자연어처리 데이터는 대부분이 텍스트 데이터로 이루어짐
# * 우리가 흔히 접하는 Exel 혹 Table 데이터 안에 수많은 텍스트 데이터 존재

# %% [markdown]
# ### **특성**
# * 문자열 역시 리스트(list), 튜플(tuple)과 마찬가지 sequence 형 자료구조를 가짐
# * 문자열은 불변 객체

# %% [markdown]
# ###  **문자열의 생성**
# 파이썬의 문자열은 작은 따옴표(')나 큰 따옴표(") 모두 구분없이 사용하여 생성 가능

# %% [markdown]
# 작은 따옴표(') 사용

# %%
'Life is too short'
# Out:
# 'Life is too short'

# %% [markdown]
# 큰 따옴표(") 사용

# %%
"you need python"
# Out:
# 'you need python'

# %% [markdown]
# 작은 따옴표/ 큰 따옴표 3개를 사용하여 여러줄의 문자열 생성

# %%
sample = '''
Life is too short,
you need python.
'''

# %%
print(sample)
# Out:
# Life is too short,
# you need python.

# %% [markdown]
# ## **문자열 출력 (포맷팅)**

# %% [markdown]
# **print() : 출력**

# %%
print('Hello pyhon')
# Out:
# Hello pyhon

# %%
print('Hello','Python')
# Out:
# Hello Python

# %% [markdown]
# end 옵션으로 출력될 마지막 글자 변경 가능(default : \n)
# * [참고] : \n 은 개행을 의미하는 특수문자

# %%
print('여기까지', end='\n')
print('끝')
# Out:
# 여기까지
# 끝

# %%
print('여기까지\n')
print('끝')
# Out:
# 여기까지
#
# 끝

# %% [markdown]
# sep 옵션으로 출력될 문자열 사이에 출력될 글자를 변경할 수 있음(default : 공백)

# %%
print('여기','까지','끝',sep='==')
# Out:
# 여기==까지==끝

# %% [markdown]
# **%를 사용한 출력**

# %%
"Hello %s" % ('world')
# Out:
# 'Hello world'

# %%
'Hello %.3f' % (0.1234)
# Out:
# 'Hello 0.123'

# %%
'Hello %d' % (12345)
# Out:
# 'Hello 12345'

# %%
'Hello %c' % ('A')
# Out:
# 'Hello A'

# %% [markdown]
# **{}와 format를 사용한 출력**

# %%
'Welcome to {}'.format('python')
# Out:
# 'Welcome to python'

# %%
'password {}'.format(4885)
# Out:
# 'password 4885'

# %% [markdown]
# 소수점 2자리까지 제한하는 경우

# %%
'원주율 {:.2f}'.format(3.141592)
# Out:
# '원주율 3.14'

# %% [markdown]
# **f 문자열 포맷팅 (python 3.6 이상만 지원)**

# %%
name = 'Boo'
age = 17
print(f'나의 이름은 {name}입니다. 나이는 {age} 살입니다.')
# Out:
# 나의 이름은 Boo입니다. 나이는 17 살입니다.

# %%
print(f'내년에 저는 {age+1} 살입니다')
# Out:
# 내년에 저는 18 살입니다

# %%
d = {'name':'Boo','age':17}
print(f"반가워요.저는 {d['name']}입니다. 저의 나이는 {d['age']} 살입니다.")
# Out:
# 반가워요.저는 Boo입니다. 저의 나이는 17 살입니다.

# %% [markdown]
# ## **문자열 길이**

# %% [markdown]
# **영문(alphabet)**

# %%
len('banana')
# Out:
# 6

# %% [markdown]
# **공백**은 길이에 포함

# %%
len('banana pen')
# Out:
# 10

# %% [markdown]
# **한글**

# %%
len('한글')
# Out:
# 2

# %% [markdown]
# ## **인덱싱 (indexing)**
# * 문자열에서 한 개의 글자를 조회하기 위해서 **[]를 활용한 인덱싱으로 조회 가능**

# %%
a = 'Python is my life'
a
# Out:
# 'Python is my life'

# %%
a[0]
# Out:
# 'P'

# %%
a[-2]
# Out:
# 'f'

# %% [markdown]
# ## **슬라이싱 (Slicing)**
# * 슬라이싱의 활용 : [start:stop:step] 을 명시하여 부분 추출 가능

# %% [markdown]
# [:]을 활용해 전체 추출

# %%
a[:]
# Out:
# 'Python is my life'

# %% [markdown]
# [start:]는 시작 index부터 끝까지 추출

# %%
a[3:]
# Out:
# 'hon is my life'

# %%
a[-4:]
# Out:
# 'life'

# %% [markdown]
# [:end]는 처음부터 **end 전까지** 추출

# %%
a[:6]
# Out:
# 'Python'

# %%
a[:-3]
# Out:
# 'Python is my l'

# %% [markdown]
# [start:end]는 start부터 end 전까지 추출

# %%
a[3:6]
# Out:
# 'hon'

# %% [markdown]
# [start:stop:step]에서 step 지정시 step 만큼 건너뛰며 추출

# %%
a[::2]
# Out:
# 'Pto sm ie'

# %% [markdown]
# 역순으로 출력하기 위에서는 step을 -1로 지정

# %%
a[::-1]
# Out:
# 'efil ym si nohtyP'

# %% [markdown]
# ### **불변(immutable)**
# * 문자열은 index를 통해 값을 수정 및 변경이 불가능
# * 하지만, 메서드(method)를 통해 변경 가능

# %%
a = 'Python is my life'

# %% [markdown]
# index에 값을 할당하여 변경하려는 경우 오류 발생

# %%
a[2] = 'Y'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-f2db0e8f1888> in <module>()
# ----> 1 a[2] = 'Y'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# del로 부분 삭제하려는 경우 오류 발생

# %%
del a[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-734682c6a06c> in <module>()
# ----> 1 del a[2]
#
# TypeError: 'str' object doesn't support item deletion

# %% [markdown]
# ## **문자열의 덧셈과 곱셈**

# %% [markdown]
# ### **연결:문자열의 덧셈**

# %% [markdown]
# 덧셈은 문자열을 연결함

# %%
a = 'Hello '
b = 'Welcome to python'

# %%
a + b
# Out:
# 'Hello Welcome to python'

# %%
a + '!!!'
# Out:
# 'Hello !!!'

# %% [markdown]
# ### **복제:문자열의 곱셈**

# %% [markdown]
# 문자열을 곱한 숫자 만큼 반복하여 생성

# %%
a*2
# Out:
# 'Hello Hello '

# %%
print('abc '*5)
print('==='*7)
# Out:
# abc abc abc abc abc
# ...

# %% [markdown]
# ## **문자열의 list, set**

# %% [markdown]
# ### **리스트(list)**
# * 문자열을 리스트(list)로 타입 변환 가능
# * 타입 변환시 한 글자를 요소로 갖는 리스트가 생성

# %%
list('ABCDE')
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %% [markdown]
# ### **세트(set)**
# * 한 글자를 요소로 갖는 세트가 생성
# * 세트의 특성상 요소를 생성한 후 중복된 글자 제거

# %%
set('AABBCCDD')
# Out:
# {'A', 'B', 'C', 'D'}

# %% [markdown]
# ## **문자열(텍스트)을 다루는 다양한 기능, 메서드(method)**
# 문자열만 가지고 있는 **고유의 기능**

# %% [markdown]
# ### **split() : 분리**
# * split은 문장을 특정 규칙에 의해 쪼개 주는 기능
# * 분리한 결과는 list형식으로 값을 return

# %%
a = 'This is a pen'

# %% [markdown]
# split()의 기본값은 공백이며, 공백을 기준으로 분리하여 리스트로 반환

# %%
a.split()
# Out:
# ['This', 'is', 'a', 'pen']

# %% [markdown]
# 기본 값인 공백에서 **특정 문자**로 지정 가능

# %%
a = 'This-is-a-pen'
a.split('-')
# Out:
# ['This', 'is', 'a', 'pen']

# %% [markdown]
# aa에서 반환된 리스트를 대입 후 index로 값 조회 가능

# %%
aa = a.split('-')
aa[0]
# Out:
# 'This'

# %%
aa[0] + ' ' + aa[2]
# Out:
# 'This a'

# %% [markdown]
# ### **join(): 합치기**
# * 결합하고자 하는 문자에 .join() 안에 리스트를 지정하여 결합 가능

# %%
a = '010 1234 5678'
'-'.join(a.split())
# Out:
# '010-1234-5678'

# %%
'-'.join('ABCDE')
# Out:
# 'A-B-C-D-E'

# %% [markdown]
# ### **lower(),upper(): 소문자/대문자로 변경**

# %%
a = 'My name is Teddy'

# %% [markdown]
# 소문자로 변경

# %%
a.lower()
# Out:
# 'my name is teddy'

# %% [markdown]
# 대문자로 변경

# %%
a.upper()
# Out:
# 'MY NAME IS TEDDY'

# %% [markdown]
# ### **startswith, endswith**

# %% [markdown]
# 시작과 끝이 맞는지 결과를 bool로 반환

# %%
a = '01-sample.png'

# %% [markdown]
# **startswith() : 시작하는**
# * 지정한 문자열로 시작하면 True, 그렇지 않으면 False를 반환

# %%
a.startswith('01')
# Out:
# True

# %%
a.startswith('01-sample.png')
# Out:
# True

# %%
a.startswith('02')
# Out:
# False

# %% [markdown]
# **endswith() : 끝나는**
# * 지정한 문자열로 끝나면 True, 그렇지 않다면 False를 반환

# %%
a.endswith('png')
# Out:
# True

# %%
a.endswith('jpg')
# Out:
# False

# %% [markdown]
# ## **replace() : 문자열 바꾸기**
# * 문자열에서 replace(바꿀대상, 바꾸려는 문자열)를 지정하여 문자열 변경
# * 결과는 복사본이 만들어져 반환

# %%
a = '01-sample.png'

# %%
a.replace('01','02')
# Out:
# '02-sample.png'

# %% [markdown]
# ## **불필요한 공백 제거**

# %%
a = '        Hello        '
print(a)
# Out:
#         Hello

# %% [markdown]
# **strip는 불필요한 공백을 제거함**

# %% [markdown]
# ### **lstrip() : 왼쪽 공백 제거**

# %%
a.lstrip()
# Out:
# 'Hello        '

# %% [markdown]
# ### **rstrip() : 오른쪽 공백 제거**

# %%
a.rstrip()
# Out:
# '        Hello'

# %% [markdown]
# ### **strip() : 양쪽 공백 제거**

# %%
a.strip()
# Out:
# 'Hello'
